# %% [markdown]
# # Werkloosheid en doden in de Verenigde Staten.
# In deze notebook zal ik twee datasets apart cleanen en vervolgens mergen zodat het gereed is om data analytics op uit te voeren.

# %%
import pandas as pd

# %% [markdown]
# ## Werkloosheid
# Ik begin met het bewerken van de dataset die werkloosheid in de Verenigde Staten laat zien.

# %%
work = pd.read_csv('Unemployment in America Per US State.csv')
work.head(20)
# Out:
#     FIPS Code            State/Area  Year  Month  \
# 0           1               Alabama  1976      1
# 1           2                Alaska  1976      1
# 2           4               Arizona  1976      1
# 3           5              Arkansas  1976      1
# 4           6            California  1976      1
# 5          37    Los Angeles County  1976      1
# 6           8              Colorado  1976      1
# 7           9           Connecticut  1976      1
# 8          10              Delaware  1976      1
# 9          11  District of Columbia  1976      1
# 10         12               Florida  1976      1
# 11         13               Georgia  1976      1
# 12         15                Hawaii  1976      1
# 13         16                 Idaho  1976      1
# 14         17              Illinois  1976      1
# 15         18               Indiana  1976      1
# 16         19                  Iowa  1976      1
# 17         20                Kansas  1976      1
# 18         21              Kentucky  1976      1
# 19         22             Louisiana  1976      1
#
#    Total Civilian Non-Institutional Population in State/Area  \
# 0                                        2,605,000
# 1                                          232,000
# 2                                        1,621,000
# 3                                        1,536,000
# 4                                       15,621,000
# 5                                        5,273,000
# 6                                        1,832,000
# 7                                        2,248,000
# 8                                          417,000
# 9                                          520,000
# 10                                       6,421,000
# 11                                       3,522,000
# 12                                         583,000
# 13                                         580,000
# 14                                       8,127,000
# 15                                       3,789,000
# 16                                       2,066,000
# 17                                       1,635,000
# 18                                       2,459,000
# 19                                       2,672,000
#
#    Total Civilian Labor Force in State/Area  \
# 0                              1,484,555
# 1                                160,183
# 2                                964,120
# 3                                889,044
# 4                              9,774,280
# 5                              3,381,856
# 6                              1,230,966
# 7                              1,442,847
# 8                                261,418
# 9                                334,691
# 10                             3,584,876
# 11                             2,244,770
# 12                               407,457
# 13                               365,606
# 14                             5,123,609
# 15                             2,425,346
# 16                             1,329,798
# 17                             1,065,059
# 18                             1,486,550
# 19                             1,517,348
#
#     Percent (%) of State/Area's Population Total Employment in State/Area  \
# 0                                     57.0                   1,386,023
# 1                                     69.0                     148,820
# 2                                     59.5                     865,871
# 3                                     57.9                     824,395
# 4                                     62.6                   8,875,685
# 5                                     64.1                   3,081,806
# 6                                     67.2                   1,160,104
# 7                                     64.2                   1,301,974
# 8                                     62.7                     240,543
# 9                                     64.4                     305,677
# 10                                    55.8                   3,238,460
# 11                                    63.7                   2,056,467
# 12                                    69.9                     367,586
# 13                                    63.0                     345,182
# 14                                    63.0                   4,786,415
# 15                                    64.0                   2,265,849
# 16                                    64.4                   1,272,281
# 17                                    65.1                   1,020,396
# 18                                    60.5                   1,402,625
# 19                                    56.8                   1,421,440
#
#     Percent (%) of Labor Force Employed in State/Area  \
# 0                                                53.2
# 1                                                64.1
# 2                                                53.4
# 3                                                53.7
# 4                                                56.8
# 5                                                58.4
# 6                                                63.3
# 7                                                57.9
# 8                                                57.7
# 9                                                58.8
# 10                                               50.4
# 11                                               58.4
# 12                                               63.1
# 13                                               59.5
# 14                                               58.9
# 15                                               59.8
# 16                                               61.6
# 17                                               62.4
# 18                                               57.0
# 19                                               53.2
#
#    Total Unemployment in State/Area  \
# 0                         98,532
# 1                         11,363
# 2                         98,249
# 3                         64,649
# 4                        898,595
# 5                        300,050
# 6                         70,862
# 7                        140,873
# 8                         20,875
# 9                         29,014
# 10                       346,416
# 11                       188,303
# 12                        39,871
# 13                        20,424
# 14                       337,194
# 15                       159,497
# 16                        57,517
# 17                        44,663
# 18                        83,925
# 19                        95,908
#
#     Percent (%) of Labor Force Unemployed in State/Area
# 0                                                 6.6
# 1                                                 7.1
# 2                                                10.2
# 3                                                 7.3
# 4                                                 9.2
# 5                                                 8.9
# 6                                                 5.8
# 7                                                 9.8
# 8                                                 8.0
# 9                                                 8.7
# 10                                                9.7
# 11                                                8.4
# 12                                                9.8
# 13                                                5.6
# 14                                                6.6
# 15                                                6.6
# 16                                                4.3
# 17                                                4.2
# 18                                                5.6
# 19                                                6.3

# %% [markdown]
# Meteen drop ik de columns 'Month' (de andere dataset heeft de informatie alleen per jaar), 'FIPS Code' (de andere dataset heeft deze info niet, ik gebruik 'State/Area' om de staat te matchen) en de column 'Total Civilian Non-Institutional Population in State/Area' (Deze is simpelweg niet nodig).

# %%
work.drop(['Month', 'FIPS Code', 'Total Civilian Non-Institutional Population in State/Area'], axis='columns', inplace=True)
len(work['State/Area'].unique())
# Out:
# 53

# %% [markdown]
# Uit de output van de vorige cell kan je zien dat er 53 unieke waardes zijn voor de column 'State/Area'. Omdat ik alleen naar de states wil kijken, zal ik de "Area's" verwijderen. Ik weet dat de VS 50 states heeft, dus 3 area's zullen eruit moeten.

# %%
work = work[~work['State/Area'].isin(['District of Columbia', 'Los Angeles County', 'New York city'])]

# %% [markdown]
# In de cell hierna voer ik de volgende stappen uit:
# 1. Column namen beknopter maken
# 2. De columns met hele getallen erin (labor_force, employement, unemployement) hebben komma's om duizenden aan te geven (bv. 1,642,981). Als ik het datatype van de column wil verandere geeft dit errors. Daarom verwijder ik de komma's.
# 3. Datatypes van de columns veranderen.
# 4. Omdat de rows in de dataset per maand waren, maar ik de maand heb verwijderd, heb ik nu 12 rows per state per jaar. Ik kies ervoor om het gemiddelde te nemen per jaar.
# 5. Ik rond the getallen af op helen, en de percentages op 1 decimaal.
# 6. Na de groupby operation zijn de state en year gebruikt voor een hierarcical index. Deze haal ik weg.
# 7. De andere dataset bevat alleen gevallen tussen de jaren 1999 en 2013, dus die wil ik ook overhouden uit deze dataset.
# 8. Laatste versie van de dataset

# %%
# Stap 1
work.rename({
    'State/Area': 'state',
    'Year': 'year',
    'Total Civilian Labor Force in State/Area': 'labor_force',
    "Percent (%) of State/Area's Population": 'labor_force_percent',
    'Total Employment in State/Area': 'employement',
    'Percent (%) of Labor Force Employed in State/Area': 'employement_percent',
    'Total Unemployment in State/Area': 'unemployement',
    'Percent (%) of Labor Force Unemployed in State/Area': 'unemployement_percent'
}, inplace=True, axis='columns')

# Stap 2
work.replace(',','', regex=True, inplace=True)

# Stap 3
work['labor_force'] = pd.to_numeric(work['labor_force'])
work['employement'] = pd.to_numeric(work['employement'])
work['unemployement'] = pd.to_numeric(work['unemployement'])

# Stap 4
work = work.groupby(['state', 'year']).mean()

# Stap 5
work[['labor_force', 'employement', 'unemployement']] = work[['labor_force', 'employement', 'unemployement']].astype(int)
work[['labor_force_percent', 'employement_percent', 'unemployement_percent']] = work[['labor_force_percent', 'employement_percent', 'unemployement_percent']].round(1)

# Stap 6
work.reset_index(inplace=True)

# Stap 7
work = work.loc[(work.year >= 1999) & (work.year <= 2013)]

# Stap 8
work.head(18)
# Out:
#       state  year  labor_force  labor_force_percent  employement  \
# 23  Alabama  1999      2150126                 64.0      2048691
# 24  Alabama  2000      2147399                 63.6      2047897
# 25  Alabama  2001      2126942                 62.7      2016673
# 26  Alabama  2002      2113208                 62.1      1988237
# 27  Alabama  2003      2128286                 62.2      2001012
# 28  Alabama  2004      2138181                 62.1      2018713
# 29  Alabama  2005      2140116                 61.5      2044937
# 30  Alabama  2006      2169932                 61.6      2083033
# 31  Alabama  2007      2180868                 61.3      2092450
# 32  Alabama  2008      2177200                 60.6      2049357
# 33  Alabama  2009      2157016                 59.6      1939466
# 34  Alabama  2010      2196694                 59.5      1968756
# 35  Alabama  2011      2201954                 59.1      1991026
# 36  Alabama  2012      2179074                 58.2      2001117
# 37  Alabama  2013      2172942                 57.7      2013764
# 70   Alaska  1999       318256                 73.6       297862
# 71   Alaska  2000       319799                 73.3       299606
# 72   Alaska  2001       321621                 72.6       301400
#
#     employement_percent  unemployement  unemployement_percent
# 23                 60.9         101434                    4.7
# 24                 60.6          99502                    4.6
# 25                 59.4         110268                    5.2
# 26                 58.4         124971                    5.9
# 27                 58.5         127273                    6.0
# 28                 58.6         119467                    5.6
# 29                 58.8          95179                    4.5
# 30                 59.1          86899                    4.0
# 31                 58.8          88418                    4.0
# 32                 57.0         127843                    5.9
# 33                 53.6         217549                   10.1
# 34                 53.3         227937                   10.4
# 35                 53.5         210927                    9.6
# 36                 53.4         177957                    8.2
# 37                 53.5         159177                    7.3
# 70                 68.9          20394                    6.4
# 71                 68.7          20193                    6.3
# 72                 68.0          20220                    6.3

# %% [markdown]
# ## Doden
# Nu zal ik werken aan de dataste die doodsoorzaken over de jaren heen laat zien.

# %%
deaths = pd.read_csv('leading_cause_death.csv')
deaths.head(10)
# Out:
#    YEAR                                     113_CAUSE_NAME  \
# 0  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 5  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 6  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 7  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 8  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 9  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                CAUSE_NAME                 STATE DEATHS   AADR
# 0  Unintentional Injuries               Alabama   2313  52.17
# 1  Unintentional Injuries                Alaska    294  55.91
# 2  Unintentional Injuries               Arizona   2214  44.79
# 3  Unintentional Injuries              Arkansas   1287  47.56
# 4  Unintentional Injuries            California   9198  28.71
# 5  Unintentional Injuries              Colorado   1519  38.98
# 6  Unintentional Injuries           Connecticut   1034  29.31
# 7  Unintentional Injuries              Delaware    267  35.25
# 8  Unintentional Injuries  District of Columbia    161  28.38
# 9  Unintentional Injuries               Florida   5961  35.73

# %% [markdown]
# Hier verwijder ik alleen de column '113_CAUSE_NAME'. Deze column is in principe hetzelfde als 'CAUSE_NAME' maar dan met officiele codes erbij die ik niet nodig heb. Daarnaast heet de 'STATE' column wat waardes die geen state zijn, dus deze verwijder ik.

# %%
deaths.drop(['113_CAUSE_NAME'], axis='columns', inplace=True)
deaths = deaths[~deaths['STATE'].isin(['District of Columbia', 'United States'])]

# %% [markdown]
# In de cell hierna voer ik de volgende stappen uit:
# 1. De column namen beknopter maken
# 2. Stap 2 was erg onverwachts: Op kaggle (waar ik de dataset vandaan heb) staat bij de column statistieken dat er geen missende waardes waren. Daar werd ik als data engineer natuurlijk heel blij van. Totdat ik de column type naar int wou veranderen en de error message kreeg dat 'kan * niet naar numeric veranderen'; de eigenaar van de dataset heeft 'x' en '*' gebruikt om missende waardes aan te duiden in plaats van deze leeg te laten. Dit heeft kaggle niet opgepakt. Dus in deze stap verander ik deze missende waardes naar NaN.
# 3. Ik verander de column naar numeriek zodat ik berekeningen kan maken met deze columns.
# 4. Voor elke missende waarde kijk ik naar de state en de cause van de andere jaren om het gemiddelde te berekenen en deze in de vullen voor 'death'
# 5. De aadr heeft meer missende values, en omdat sommige states helemaal geen aadr hebben in de datasets kan ik de vorige methode niet uitvoeren. Daarom gebruik ik een methode die pandas zelf levert.

# %%
# Stap 1
deaths.rename({
    'YEAR': 'year',
    'CAUSE_NAME': 'cause',
    'STATE': 'state',
    'DEATHS': 'deaths',
    'AADR': 'aadr'
}, inplace=True, axis='columns')

# Stap 2
deaths.deaths = deaths.deaths.replace('x', pd.NA)
deaths.aadr = deaths.aadr.replace(['x', '*'], pd.NA)

# Stap 3
deaths.deaths = pd.to_numeric(deaths.deaths, errors='coerce')
deaths.aadr = pd.to_numeric(deaths.aadr, errors='coerce')

# Stap 4
grouped_data = deaths.groupby(['state', 'cause'])
mean_deaths = grouped_data['deaths'].transform(lambda x: x.fillna(x.mean()))
deaths.deaths = mean_deaths
deaths.deaths = deaths.deaths.astype(int)

# Stap 5
deaths['aadr'] = deaths['aadr'].fillna(method='ffill')
deaths.aadr = deaths.aadr.astype(int)

deaths.loc[deaths.state == 'Alabama'].head(10)
# Out:
#      year                                              cause    state  deaths  \
# 0    1999                             Unintentional Injuries  Alabama    2313
# 53   1999                                         All Causes  Alabama   44806
# 104  1999                                Alzheimer's disease  Alabama     772
# 156  1999                                           Homicide  Alabama     438
# 208  1999                                             Stroke  Alabama    3148
# 260  1999                Chronic liver disease and cirrhosis  Alabama     412
# 312  1999                                               CLRD  Alabama    2179
# 364  1999                                           Diabetes  Alabama    1341
# 417  1999                                  Diseases of Heart  Alabama   13419
# 469  1999  Essential hypertension and hypertensive renal ...  Alabama     313
#
#      aadr
# 0      52
# 53   1009
# 104    17
# 156     9
# 208    71
# 260     9
# 312    48
# 364    30
# 417   302
# 469     7

# %% [markdown]
# Nu heb ik een ander probleem. De doodsoorzaken zitten allemaal in 1 column. Maar om de datasets samen te voegen moet ik per state een uniek jaartal hebben, en niet 1 state met hetzelfde jaartal meerder keren voor elke doodsoorzaak. Daarom kies ik ervoor om voor elke doodsoorzaak een column te maken met behulp van de pivot_table functie.

# %%
deaths_pivot_table = pd.pivot_table(deaths, index=['state', 'year'], values='deaths', columns=['cause'])
deaths_pivot_table.reset_index(inplace=True)
deaths_pivot_table.loc[deaths_pivot_table.state == 'Alabama'].head(20)
# Out:
# cause    state  year  All Causes  Alzheimer's disease  CLRD  Cancer  \
# 0      Alabama  1999       44806                  772  2179    9506
# 1      Alabama  2000       45062                  895  2057    9807
# 2      Alabama  2001       45316                 1103  2204    9801
# 3      Alabama  2002       46069                 1189  2328    9698
# 4      Alabama  2003       46716                 1268  2434    9812
# 5      Alabama  2004       46121                 1385  2361    9756
# 6      Alabama  2005       47090                 1501  2382    9913
# 7      Alabama  2006       46977                 1497  2309    9899
# 8      Alabama  2007       46696                 1517  2530   10025
# 9      Alabama  2008       47707                 1518  2733   10182
# 10     Alabama  2009       47470                 1521  2770   10289
# 11     Alabama  2010       48038                 1523  2866   10196
# 12     Alabama  2011       48681                 1486  2912   10233
# 13     Alabama  2012       49301                 1390  3015   10276
# 14     Alabama  2013       50189                 1398  3043   10328
#
# cause  Chronic liver disease and cirrhosis  Diabetes  Diseases of Heart  \
# 0                                      412      1341              13419
# 1                                      407      1321              13406
# 2                                      445      1344              13207
# 3                                      425      1486              13197
# 4                                      440      1414              13150
# 5                                      477      1449              12774
# 6                                      478      1429              12869
# 7                                      489      1453              12583
# 8                                      505      1313              11926
# 9                                      489      1386              12074
# 10                                     488      1259              12021
# 11                                     504      1302              12083
# 12                                     551      1278              11942
# 13                                     622      1300              12036
# 14                                     577      1349              12472
#
# cause  Essential hypertension and hypertensive renal disease  Homicide  \
# 0                                                    313           438
# 1                                                    291           444
# 2                                                    369           425
# 3                                                    343           416
# 4                                                    402           434
# 5                                                    413           369
# 6                                                    428           433
# 7                                                    456           445
# 8                                                    475           480
# 9                                                    501           454
# 10                                                   523           412
# 11                                                   549           391
# 12                                                   539           392
# 13                                                   528           405
# 14                                                   585           417
#
# cause  Influenza and pneumonia  Kidney Disease  Parkinson's disease  \
# 0                         1228             979                  207
# 1                         1138             939                  214
# 2                         1105             974                  239
# 3                         1218            1032                  232
# 4                         1157            1062                  265
# 5                          994            1049                  256
# 6                         1011            1036                  306
# 7                          918            1104                  291
# 8                          898            1051                  321
# 9                          912            1107                  348
# 10                         952            1180                  363
# 11                         942            1184                  342
# 12                         951            1047                  374
# 13                         942            1035                  385
# 14                        1035            1057                  425
#
# cause  Pneumonitis due to solids and liquids  Septicemia  Stroke  Suicide  \
# 0                                        306         691    3148      555
# 1                                        289         775    3183      583
# 2                                        290         771    2998      512
# 3                                        323         765    3201      514
# 4                                        309         854    3028      521
# 5                                        287         756    2986      541
# 6                                        318         848    2952      535
# 7                                        273         836    2740      580
# 8                                        288         769    2747      592
# 9                                        256         899    2863      604
# 10                                       241         866    2675      673
# 11                                       290         869    2619      679
# 12                                       305         912    2568      654
# 13                                       305         895    2628      724
# 14                                       284         965    2604      721
#
# cause  Unintentional Injuries
# 0                        2313
# 1                        2093
# 2                        2211
# 3                        2228
# 4                        2179
# 5                        2403
# 6                        2395
# 7                        2506
# 8                        2542
# 9                        2509
# 10                       2351
# 11                       2394
# 12                       2662
# 13                       2283
# 14                       2329

# %% [markdown]
# Dit maakt weer een ander probleem. Zoals je kunt zien in de column hierboven is een hele belangrijke column die we eerst hadden weggelaten. Dit is de aadr column. De aadr column is erg belangrijk, omdat dit de column is waar we de verschillende staten mee moeten vergelijken. Definitie van aadr: 'The age-adjusted rates are rates that would have existed if the population under study had the same age distribution as the "standard" population. Therefore, they are summary measures adjusted for differences in age distributions.' (health.mo.gov). Alle states hebben andere bevolkingsdistributies. De aadr zorgt ervoor dat deze op gelijke grond komt zodat we deze kunnen vergelijken. Kortom: een belangrijke column. We zullen iets soortsgelijks doen voor de aadr column als we voor de causes column hebben gedaan.

# %%
death_causes = deaths_pivot_table.columns

aadr_column_names = [cause + '_aadr' for cause in death_causes]
aadr_column_names = aadr_column_names[2:]
pivot_table_aadr = pd.pivot_table(data=deaths, index=['state', 'year'], values='aadr', columns='cause')

pivot_table_aadr.columns = aadr_column_names
pivot_table_aadr.reset_index(inplace=True)
pivot_table_aadr.head(20)
# Out:
#       state  year  All Causes_aadr  Alzheimer's disease_aadr  CLRD_aadr  \
# 0   Alabama  1999             1009                        17         48
# 1   Alabama  2000             1004                        20         45
# 2   Alabama  2001             1002                        25         48
# 3   Alabama  2002             1013                        27         50
# 4   Alabama  2003             1020                        28         52
# 5   Alabama  2004              998                        31         50
# 6   Alabama  2005             1001                        33         50
# 7   Alabama  2006              979                        32         47
# 8   Alabama  2007              957                        32         51
# 9   Alabama  2008              959                        32         54
# 10  Alabama  2009              940                        31         54
# 11  Alabama  2010              939                        31         55
# 12  Alabama  2011              933                        29         55
# 13  Alabama  2012              926                        27         55
# 14  Alabama  2013              925                        26         54
# 15   Alaska  1999              838                        11         56
# 16   Alaska  2000              869                        21         47
# 17   Alaska  2001              831                        18         49
# 18   Alaska  2002              802                        25         47
# 19   Alaska  2003              843                        22         46
#
#     Cancer_aadr  Chronic liver disease and cirrhosis_aadr  Diabetes_aadr  \
# 0           210                                         9             30
# 1           215                                         8             29
# 2           213                                         9             29
# 3           208                                         9             32
# 4           208                                         9             30
# 5           204                                         9             30
# 6           204                                         9             29
# 7           199                                         9             29
# 8           198                                         9             26
# 9           197                                         9             27
# 10          196                                         9             24
# 11          191                                         9             24
# 12          187                                         9             23
# 13          185                                        11             23
# 14          182                                        10             24
# 15          190                                         9             23
# 16          208                                         9             27
# 17          193                                        10             22
# 18          189                                         9             22
# 19          188                                        10             27
#
#     Diseases of Heart_aadr  \
# 0                      302
# 1                      299
# 2                      292
# 3                      291
# 4                      288
# 5                      278
# 6                      274
# 7                      262
# 8                      244
# 9                      243
# 10                     237
# 11                     235
# 12                     228
# 13                     225
# 14                     228
# 15                     198
# 16                     211
# 17                     189
# 18                     169
# 19                     185
#
#     Essential hypertension and hypertensive renal disease_aadr  Homicide_aadr  \
# 0                                                   7                       9
# 1                                                   6                      10
# 2                                                   8                       9
# 3                                                   7                       9
# 4                                                   8                       9
# 5                                                   9                       8
# 6                                                   9                       9
# 7                                                   9                       9
# 8                                                   9                      10
# 9                                                  10                       9
# 10                                                 10                       8
# 11                                                 10                       8
# 12                                                 10                       8
# 13                                                  9                       8
# 14                                                 10                       8
# 15                                                  7                       8
# 16                                                  6                       5
# 17                                                  8                       5
# 18                                                  7                       5
# 19                                                  8                       6
#
#     Influenza and pneumonia_aadr  Kidney Disease_aadr  \
# 0                             28                   22
# 1                             25                   21
# 2                             24                   21
# 3                             27                   22
# 4                             25                   23
# 5                             22                   22
# 6                             22                   22
# 7                             19                   23
# 8                             18                   21
# 9                             18                   22
# 10                            19                   23
# 11                            18                   23
# 12                            18                   20
# 13                            17                   19
# 14                            19                   19
# 15                            19                   13
# 16                            16                   11
# 17                            13                    7
# 18                            19                    6
# 19                            21                    8
#
#     Parkinson's disease_aadr  Pneumonitis due to solids and liquids_aadr  \
# 0                          4                                           7
# 1                          4                                           6
# 2                          5                                           6
# 3                          5                                           7
# 4                          5                                           6
# 5                          5                                           6
# 6                          6                                           6
# 7                          6                                           5
# 8                          6                                           6
# 9                          7                                           5
# 10                         7                                           4
# 11                         6                                           5
# 12                         7                                           5
# 13                         7                                           5
# 14                         8                                           5
# 15                         4                                           7
# 16                         4                                           6
# 17                         5                                           6
# 18                         5                                           7
# 19                         5                                           6
#
#     Septicemia_aadr  Stroke_aadr  Suicide_aadr  Unintentional Injuries_aadr
# 0                15           71            12                           52
# 1                17           71            13                           47
# 2                17           66            11                           49
# 3                16           71            11                           49
# 4                18           66            11                           48
# 5                16           65            11                           52
# 6                18           63            11                           51
# 7                17           57            12                           53
# 8                15           56            12                           53
# 9                17           58            12                           52
# 10               16           53            13                           49
# 11               16           51            13                           49
# 12               17           49            13                           54
# 13               16           49            14                           46
# 14               17           48            14                           47
# 15                8           71            16                           55
# 16               17           66            21                           64
# 17                7           57            15                           60
# 18                7           55            20                           59
# 19                4           62            20                           55

# %% [markdown]
# Nu zal ik de twee death datasets mergen.

# %%
deaths_final = pd.merge(deaths_pivot_table, pivot_table_aadr, on=['state', 'year'])
deaths_final.head(5)
# Out:
#      state  year  All Causes  Alzheimer's disease  CLRD  Cancer  \
# 0  Alabama  1999       44806                  772  2179    9506
# 1  Alabama  2000       45062                  895  2057    9807
# 2  Alabama  2001       45316                 1103  2204    9801
# 3  Alabama  2002       46069                 1189  2328    9698
# 4  Alabama  2003       46716                 1268  2434    9812
#
#    Chronic liver disease and cirrhosis  Diabetes  Diseases of Heart  \
# 0                                  412      1341              13419
# 1                                  407      1321              13406
# 2                                  445      1344              13207
# 3                                  425      1486              13197
# 4                                  440      1414              13150
#
#    Essential hypertension and hypertensive renal disease  ...  \
# 0                                                313      ...
# 1                                                291      ...
# 2                                                369      ...
# 3                                                343      ...
# 4                                                402      ...
#
#    Essential hypertension and hypertensive renal disease_aadr  Homicide_aadr  \
# 0                                                  7                       9
# 1                                                  6                      10
# 2                                                  8                       9
# 3                                                  7                       9
# 4                                                  8                       9
#
#    Influenza and pneumonia_aadr  Kidney Disease_aadr  \
# 0                            28                   22
# 1                            25                   21
# 2                            24                   21
# 3                            27                   22
# 4                            25                   23
#
#    Parkinson's disease_aadr  Pneumonitis due to solids and liquids_aadr  \
# 0                         4                                           7
# 1                         4                                           6
# 2                         5                                           6
# 3                         5                                           7
# 4                         5                                           6
#
#    Septicemia_aadr  Stroke_aadr  Suicide_aadr  Unintentional Injuries_aadr
# 0               15           71            12                           52
# 1               17           71            13                           47
# 2               17           66            11                           49
# 3               16           71            11                           49
# 4               18           66            11                           48
#
# [5 rows x 36 columns]

# %% [markdown]
# En nu zal ik de work en death datasets samenvoegen. Nu heb ik 1 bewerkte dataset die ik export als csv, waar ik in Power BI verder mee zal werken.

# %%
final_dataset = pd.merge(deaths_final, work, on=['state', 'year'])
final_dataset.to_csv('death_work.csv')
final_dataset.head(5)
# Out:
#      state  year  All Causes  Alzheimer's disease  CLRD  Cancer  \
# 0  Alabama  1999       44806                  772  2179    9506
# 1  Alabama  2000       45062                  895  2057    9807
# 2  Alabama  2001       45316                 1103  2204    9801
# 3  Alabama  2002       46069                 1189  2328    9698
# 4  Alabama  2003       46716                 1268  2434    9812
#
#    Chronic liver disease and cirrhosis  Diabetes  Diseases of Heart  \
# 0                                  412      1341              13419
# 1                                  407      1321              13406
# 2                                  445      1344              13207
# 3                                  425      1486              13197
# 4                                  440      1414              13150
#
#    Essential hypertension and hypertensive renal disease  ...  \
# 0                                                313      ...
# 1                                                291      ...
# 2                                                369      ...
# 3                                                343      ...
# 4                                                402      ...
#
#    Septicemia_aadr  Stroke_aadr  Suicide_aadr  Unintentional Injuries_aadr  \
# 0               15           71            12                           52
# 1               17           71            13                           47
# 2               17           66            11                           49
# 3               16           71            11                           49
# 4               18           66            11                           48
#
#    labor_force  labor_force_percent  employement  employement_percent  \
# 0      2150126                 64.0      2048691                 60.9
# 1      2147399                 63.6      2047897                 60.6
# 2      2126942                 62.7      2016673                 59.4
# 3      2113208                 62.1      1988237                 58.4
# 4      2128286                 62.2      2001012                 58.5
#
#    unemployement  unemployement_percent
# 0         101434                    4.7
# 1          99502                    4.6
# 2         110268                    5.2
# 3         124971                    5.9
# 4         127273                    6.0
#
# [5 rows x 42 columns]
